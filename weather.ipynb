# %%
# Reading in the initial data
import pandas as pd
weather = pd.read_csv("local_weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                     NAME   ACMH  \
# DATE
# 1969-06-01  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   50.0
# 1969-06-02  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   70.0
# 1969-06-03  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US  100.0
# 1969-06-04  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   90.0
# 1969-06-05  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   50.0
# ...                 ...                                      ...    ...
# 2023-09-16  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2023-09-17  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2023-09-18  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2023-09-19  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2023-09-20  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
#
#              ACSH  AWND  FMTM    PGTM  PRCP  PSUN  SNOW  ...  WT10  WT11  \
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.502798
# ACSH       0.502798
# AWND       0.268868
# FMTM       0.486413
# PGTM       0.263978
# PRCP       0.000000
# PSUN       0.731434
# SNOW       0.000050
# SNWD       0.000050
# TAVG       0.672246
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.428485
# WDF1       0.502849
# WDF2       0.497303
# WDF5       0.499672
# WDFG       0.506226
# WESD       0.705369
# WSF1       0.502849
# WSF2       0.497303
# WSF5       0.499571
# WSFG       0.506075
# WT01       0.519587
# WT02       0.933753
# WT03       0.826519
# WT04       0.997883
# WT05       0.984421
# WT06       0.997378
# WT07       0.996471
# WT08       0.769398
# WT09       0.998689
# WT10       0.999950
# WT11       0.998992
# WT13       0.869221
# WT14       0.970860
# WT15       0.999193
# WT16       0.675271
# WT17       0.999093
# WT18       0.998387
# WT21       0.990875
# WV03       0.999698
# dtype: float64

# %%
core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()

# %%
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1969-06-01    0.00   0.0         0.0        90        72
# 1969-06-02    0.18   0.0         0.0        85        62
# 1969-06-03    0.06   0.0         0.0        80        60
# 1969-06-04    1.27   0.0         0.0        66        60
# 1969-06-05    0.00   0.0         0.0        78        56
# ...            ...   ...         ...       ...       ...
# 2023-09-16    0.04   0.0         0.0        92        73
# 2023-09-17    0.00   0.0         0.0        95        73
# 2023-09-18    0.00   0.0         0.0        94        69
# 2023-09-19    0.00   0.0         0.0        93        68
# 2023-09-20    0.00   0.0         0.0        93        71
#
# [19835 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.00000
# snow          0.00005
# snow_depth    0.00005
# temp_max      0.00000
# temp_min      0.00000
# dtype: float64

# %%
core_weather["snow"].value_counts()
# Out:
# snow
# 0.0    19817
# 1.4        3
# 1.0        3
# 0.1        3
# 0.3        2
# 0.4        2
# 2.0        1
# 1.1        1
# 1.7        1
# 0.6        1
# Name: count, dtype: int64

# %%
core_weather[pd.isnull(core_weather["snow"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1996-11-19    0.01   NaN         0.0        79        62

# %%
core_weather.loc["1996-11-10":"1996-12-05",:]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1996-11-10    0.00   0.0         0.0        75        42
# 1996-11-11    0.00   0.0         0.0        80        47
# 1996-11-12    0.00   0.0         0.0        78        53
# 1996-11-13    0.00   0.0         0.0        76        57
# 1996-11-14    0.00   0.0         0.0        78        57
# 1996-11-15    0.00   0.0         0.0        76        62
# 1996-11-16    0.05   0.0         0.0        79        69
# 1996-11-17    0.00   0.0         0.0        82        58
# 1996-11-18    0.00   0.0         0.0        67        58
# 1996-11-19    0.01   NaN         0.0        79        62
# 1996-11-20    0.00   0.0         0.0        82        67
# 1996-11-21    0.00   0.0         0.0        81        66
# 1996-11-22    0.00   0.0         0.0        66        60
# 1996-11-23    0.00   0.0         0.0        82        61
# 1996-11-24    2.80   0.0         0.0        74        37
# ...

# %%
core_weather["snow"] = core_weather["snow"].fillna(0)

# %%
core_weather["snow_depth"] = core_weather["snow_depth"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.0
# snow          0.0
# snow_depth    0.0
# temp_max      0.0
# temp_min      0.0
# dtype: float64

# %%
core_weather.dtypes
# Out:
# precip        float64
# snow          float64
# snow_depth    float64
# temp_max        int64
# temp_min        int64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1969-06-01', '1969-06-02', '1969-06-03', '1969-06-04', '1969-06-05',
#        '1969-06-06', '1969-06-07', '1969-06-08', '1969-06-09', '1969-06-10',
#        ...
#        '2023-09-11', '2023-09-12', '2023-09-13', '2023-09-14', '2023-09-15',
#        '2023-09-16', '2023-09-17', '2023-09-18', '2023-09-19', '2023-09-20'],
#       dtype='object', name='DATE', length=19835)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1969-06-01', '1969-06-02', '1969-06-03', '1969-06-04',
#                '1969-06-05', '1969-06-06', '1969-06-07', '1969-06-08',
#                '1969-06-09', '1969-06-10',
#                ...
#                '2023-09-11', '2023-09-12', '2023-09-13', '2023-09-14',
#                '2023-09-15', '2023-09-16', '2023-09-17', '2023-09-18',
#                '2023-09-19', '2023-09-20'],
#               dtype='datetime64[ns]', name='DATE', length=19835, freq=None)

# %%
core_weather.index.year
# Out:
# Index([1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969,
#        ...
#        2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#       dtype='int32', name='DATE', length=19835)

# %%
core_weather.index.month
# Out:
# Index([6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        ...
#        9, 9, 9, 9, 9, 9, 9, 9, 9, 9],
#       dtype='int32', name='DATE', length=19835)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip        0
# snow          0
# snow_depth    0
# temp_max      0
# temp_min      0
# dtype: int64

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1969    23.96
# 1970    48.19
# 1971    37.83
# 1972    50.80
# 1973    70.16
# 1974    49.29
# 1975    50.97
# 1976    54.62
# 1977    34.94
# 1978    44.93
# 1979    58.97
# 1980    38.99
# 1981    55.98
# 1982    42.87
# 1983    53.21
# 1984    48.19
# 1985    49.14
# 1986    44.93
# 1987    40.60
# 1988    22.93
# 1989    52.73
# 1990    40.37
# 1991    61.09
# 1992    52.33
# 1993    57.99
# 1994    43.15
# 1995    44.63
# 1996    42.81
# 1997    60.22
# 1998    54.84
# 1999    28.04
# 2000    47.63
# 2001    71.19
# 2002    59.71
# 2003    45.74
# 2004    65.06
# 2005    41.21
# 2006    57.86
# 2007    65.52
# 2008    53.00
# 2009    47.01
# 2010    42.72
# 2011    24.57
# 2012    42.32
# 2013    38.84
# 2014    43.72
# 2015    70.03
# 2016    60.96
# 2017    79.69
# 2018    56.02
# 2019    51.93
# 2020    44.77
# 2021    50.87
# 2022    41.30
# 2023    32.69
# Name: precip, dtype: float64

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1969-06-01    0.00   0.0         0.0        90        72    85.0
# 1969-06-02    0.18   0.0         0.0        85        62    80.0
# 1969-06-03    0.06   0.0         0.0        80        60    66.0
# 1969-06-04    1.27   0.0         0.0        66        60    78.0
# 1969-06-05    0.00   0.0         0.0        78        56    86.0
# ...            ...   ...         ...       ...       ...     ...
# 2023-09-16    0.04   0.0         0.0        92        73    95.0
# 2023-09-17    0.00   0.0         0.0        95        73    94.0
# 2023-09-18    0.00   0.0         0.0        94        69    93.0
# 2023-09-19    0.00   0.0         0.0        93        68    93.0
# 2023-09-20    0.00   0.0         0.0        93        71     NaN
#
# [19835 rows x 6 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1969-06-01    0.00   0.0         0.0        90        72    85.0
# 1969-06-02    0.18   0.0         0.0        85        62    80.0
# 1969-06-03    0.06   0.0         0.0        80        60    66.0
# 1969-06-04    1.27   0.0         0.0        66        60    78.0
# 1969-06-05    0.00   0.0         0.0        78        56    86.0
# ...            ...   ...         ...       ...       ...     ...
# 2023-09-15    0.02   0.0         0.0        91        71    92.0
# 2023-09-16    0.04   0.0         0.0        92        73    95.0
# 2023-09-17    0.00   0.0         0.0        95        73    94.0
# 2023-09-18    0.00   0.0         0.0        94        69    93.0
# 2023-09-19    0.00   0.0         0.0        93        68    93.0
#
# [19834 rows x 6 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2020-12-31"]

# %%
test = core_weather.loc["2021-01-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 4.30060367533497

# %%
# Combine the actuals and the predictions and convert the predictions to a panda series and concatenate them on axis 1
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
# Name the columns
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    59.0    58.398438
# 2021-01-02    69.0    61.529633
# 2021-01-03    76.0    68.223304
# 2021-01-04    71.0    74.799400
# 2021-01-05    75.0    71.376944
# ...            ...          ...
# 2023-09-15    92.0    90.036706
# 2023-09-16    95.0    91.063124
# 2023-09-17    94.0    93.340198
# 2023-09-18    93.0    91.990241
# 2023-09-19    93.0    91.094011
#
# [992 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# Look at the coefficient of the regression model
reg.coef_
# Out:
# array([-1.05272645,  0.74498815,  0.15124216])

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]
    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])
    error = mean_absolute_error(test["target"], predictions)
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
# Look back the previous 30 days and then find the average of a certain column
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target   month_max
# DATE
# 1969-06-01    0.00   0.0         0.0        90        72    85.0         NaN
# 1969-06-02    0.18   0.0         0.0        85        62    80.0         NaN
# 1969-06-03    0.06   0.0         0.0        80        60    66.0         NaN
# 1969-06-04    1.27   0.0         0.0        66        60    78.0         NaN
# 1969-06-05    0.00   0.0         0.0        78        56    86.0         NaN
# ...            ...   ...         ...       ...       ...     ...         ...
# 2023-09-15    0.02   0.0         0.0        91        71    92.0  100.600000
# 2023-09-16    0.04   0.0         0.0        92        73    95.0  100.166667
# 2023-09-17    0.00   0.0         0.0        95        73    94.0   99.900000
# 2023-09-18    0.00   0.0         0.0        94        69    93.0   99.600000
# 2023-09-19    0.00   0.0         0.0        93        68    93.0   99.100000
#
# [19834 rows x 7 columns]

# %%
# Calculate the difference between the monthly average of a temperature to the temperature of a given day
core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

# %%
# Calculate the ration between the max temperature and the min temperature
core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
# Add extra predictors
predictors = ["precip", "temp_max", "temp_min", "month_max", "month_day_max", "max_min"]

# %%
# Remove the first 30 rows of core_weather
core_weather = core_weather.iloc[30:,:].copy()

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# 4.158734543436562

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# Group by month in the temperature max column and use the previous rows to calculate the means
core_weather["monthly_avg"] = core_weather["temp_max"].groupby(core_weather.index.month).transform(lambda x: x.expanding(1).mean())

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target   month_max  \
# DATE
# 1969-07-01    0.00   0.0         0.0        98        75    98.0   91.166667
# 1969-07-02    0.00   0.0         0.0        98        72    98.0   91.600000
# 1969-07-03    0.00   0.0         0.0        98        72    99.0   92.200000
# 1969-07-04    0.00   0.0         0.0        99        71    93.0   93.300000
# 1969-07-05    1.03   0.0         0.0        93        72    95.0   93.800000
# ...            ...   ...         ...       ...       ...     ...         ...
# 2023-09-15    0.02   0.0         0.0        91        71    92.0  100.600000
# 2023-09-16    0.04   0.0         0.0        92        73    95.0  100.166667
# 2023-09-17    0.00   0.0         0.0        95        73    94.0   99.900000
# 2023-09-18    0.00   0.0         0.0        94        69    93.0   99.600000
# 2023-09-19    0.00   0.0         0.0        93        68    93.0   99.100000
#
# ...

# %%
# Calculate the day of the year average
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year).transform(lambda x: x.expanding(1).mean())

# %%
predictors = ["precip", "temp_max", "temp_min", "month_max", "month_day_max", "max_min", "day_of_year_avg", "monthly_avg"]

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# 4.167884145109004

# %%
reg.coef_
# Out:
# array([ -1.49475166,   0.22994266,   0.23812893,   0.26259029,
#        -13.43033475,   6.07082994,   0.14560565,   0.16056148])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.069217
# snow              -0.062436
# snow_depth        -0.029646
# temp_max           0.887233
# temp_min           0.808984
# target             1.000000
# month_max          0.806965
# month_day_max     -0.418751
# max_min           -0.357426
# monthly_avg        0.818091
# day_of_year_avg    0.833971
# Name: target, dtype: float64

# %%
# Calculate the absolute difference between the actual value and the combined
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
# Look at the differences between what the actual value was and the prediction
combined.sort_values("diff", ascending=False).head()
# Out:
#             actual  predictions       diff
# DATE
# 2022-12-22    32.0    65.263000  33.263000
# 2022-03-07    51.0    72.609833  21.609833
# 2022-02-02    48.0    68.791763  20.791763
# 2022-02-03    33.0    53.585731  20.585731
# 2022-01-07    75.0    55.252335  19.747665
